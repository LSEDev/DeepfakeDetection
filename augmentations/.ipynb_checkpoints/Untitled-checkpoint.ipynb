# %%
import pandas as pd

def get_top_policies(df, k):
        """Prints and returns top-k policies

        Policies are ordered by their expected accuracy increas
        Args:
            k (int) top-k
        Returns
            pandas.DataFrame: top-k policies as dataframe
        """
        trial_avg_val_acc_df = (
            df.drop_duplicates(["trial_no", "sample_no"])
            .groupby("trial_no")
            .mean()["mean_late_val_acc"]
            .reset_index()
        )[["trial_no", "mean_late_val_acc"]]

        x_df = pd.merge(
            df.drop(columns=["mean_late_val_acc"]),
            trial_avg_val_acc_df,
            on="trial_no",
            how="left",
        )

        x_df = x_df.sort_values("mean_late_val_acc", ascending=False)

        baseline_val_acc = x_df[x_df["trial_no"] == 0]["mean_late_val_acc"].values[0]

        x_df["expected_accuracy_increase(%)"] = (
            x_df["mean_late_val_acc"] - baseline_val_acc
        )*100

        top_df = x_df.drop_duplicates(["trial_no"]).sort_values(
            "mean_late_val_acc", ascending=False
        )[:k]

        SELECT = [
            "trial_no",
            'A_aug1_type', 'A_aug1_magnitude', 'A_aug2_type', 'A_aug2_magnitude',
            'B_aug1_type', 'B_aug1_magnitude', 'B_aug2_type', 'B_aug2_magnitude',
            'C_aug1_type', 'C_aug1_magnitude', 'C_aug2_type', 'C_aug2_magnitude',
            'D_aug1_type', 'D_aug1_magnitude', 'D_aug2_type', 'D_aug2_magnitude',
            'E_aug1_type', 'E_aug1_magnitude', 'E_aug2_type', 'E_aug2_magnitude',
            "mean_late_val_acc", "expected_accuracy_increase(%)"
        ]
        top_df = top_df[SELECT]

#         print(f"top-{k} policies:", k)
#         print(top_df)

        return top_df

get_top_policies(pd.read_csv('./autoaugment_results.csv'), 105)
# Out:
#      trial_no              A_aug1_type  A_aug1_magnitude  \
# 310        15          horizontal-flip             0.357
# 581        29           gamma-contrast             0.087
# 170         8                   rotate             0.097
# 540        27                    shear             0.809
# 610        30                  dropout             0.756
# 37          1           gamma-contrast             0.844
# 516        25                   invert             0.136
# 539        26                  sharpen             0.170
# 142         7                   invert             0.533
# 80          4                  sharpen             0.675
# 565        28          horizontal-flip             0.126
# 259        12                   clouds             0.196
# 139         6           gamma-contrast             0.704
# 275        13           gamma-contrast             0.580
# 287        14                   invert             0.372
# 60          3                 brighten             0.902
# 192         9                   emboss             0.420
# 459        22          horizontal-flip             0.286
# 480        24              translate-y             0.252
# 430        21  additive-gaussian-noise             0.137
# 400        20                    shear             0.755
# 359        17           coarse-dropout             0.218
# 59          2                  dropout             0.801
# 332        16                   rotate             0.275
# 388        19                    shear             0.762
# 371        18           coarse-dropout             0.340
# 474        23                     crop             0.174
# 100         5       coarse-salt-pepper             0.918
# 205        10       coarse-salt-pepper             0.395
# 226        11       coarse-salt-pepper             0.110
# 2           0                   rotate             0.000
#
#                    A_aug2_type  A_aug2_magnitude                B_aug1_type  \
# 310              vertical-flip             0.296                    dropout
# 581         coarse-salt-pepper             0.734                     rotate
# 170              vertical-flip             0.260             coarse-dropout
# 540             gamma-contrast             0.856                     clouds
# 610                     clouds             0.181                    dropout
# 37          coarse-salt-pepper             0.847                   brighten
# 516                    sharpen             0.240              vertical-flip
# 539                    sharpen             0.723  add-to-hue-and-saturation
# 142                translate-x             0.395                   brighten
# 80                     sharpen             0.778            horizontal-flip
# 565                       crop             0.688         coarse-salt-pepper
# 259    additive-gaussian-noise             0.799                     rotate
# 139                translate-y             0.433                     clouds
# 275              vertical-flip             0.196                        fog
# 287    additive-gaussian-noise             0.852             gamma-contrast
# 60               gaussian-blur             0.970                     invert
# 192              gaussian-blur             0.365                       crop
# 459             gamma-contrast             0.791                        fog
# 480  add-to-hue-and-saturation             0.285                     rotate
# 430              vertical-flip             0.168                translate-y
# 400              vertical-flip             0.223             gamma-contrast
# 359                     invert             0.458                     clouds
# 59              coarse-dropout             0.679                        fog
# 332                    sharpen             0.000                        fog
# 388              vertical-flip             0.137             coarse-dropout
# 371              vertical-flip             0.279                     rotate
# 474              vertical-flip             0.514                       crop
# 100                translate-x             0.565         coarse-salt-pepper
# 205                     invert             0.405                     emboss
# 226                     emboss             0.178                     rotate
# 2                       rotate             0.000                     rotate
#
#      B_aug1_magnitude              B_aug2_type  B_aug2_magnitude  \
# 310             0.447            vertical-flip             0.248
# 581             0.031       coarse-salt-pepper             0.244
# 170             0.448            gaussian-blur             0.352
# 540             0.183              translate-y             0.206
# 610             0.056          horizontal-flip             0.254
# 37              0.384              translate-y             0.057
# 516             0.444                  sharpen             0.200
# 539             0.293                   clouds             0.833
# 142             0.475                  dropout             0.716
# 80              0.663                     crop             0.623
# 565             0.122           gamma-contrast             0.020
# 259             0.864                     crop             0.284
# 139             0.396       coarse-salt-pepper             0.639
# 275             0.101              translate-y             0.270
# 287             0.379           gamma-contrast             0.266
# 60              0.171                   emboss             0.751
# 192             0.231                   clouds             0.944
# 459             0.457           coarse-dropout             0.176
# 480             0.792  additive-gaussian-noise             0.113
# 430             0.583            vertical-flip             0.134
# 400             0.023  additive-gaussian-noise             0.170
# 359             0.633  additive-gaussian-noise             0.177
# 59              0.582           coarse-dropout             0.759
# 332             0.730            gaussian-blur             0.085
# 388             0.777                 brighten             0.903
# 371             0.047            gaussian-blur             0.565
# 474             0.395            gaussian-blur             0.060
# 100             0.509          horizontal-flip             0.921
# 205             0.218                   clouds             0.505
# 226             0.329                   emboss             0.620
# 2               0.000                   rotate             0.000
#
#                    C_aug1_type  ...                D_aug1_type  \
# 310                    dropout  ...                   brighten
# 581                translate-x  ...                   brighten
# 170                    dropout  ...             coarse-dropout
# 540                       crop  ...    additive-gaussian-noise
# 610                      shear  ...             coarse-dropout
# 37                 translate-y  ...                     emboss
# 516              vertical-flip  ...              vertical-flip
# 539                       crop  ...                        fog
# 142                translate-y  ...                     rotate
# 80                      invert  ...              gaussian-blur
# 565                        fog  ...                      shear
# 259  add-to-hue-and-saturation  ...                      shear
# 139         coarse-salt-pepper  ...                     rotate
# 275                     clouds  ...                translate-y
# 287                     rotate  ...                    dropout
# 60                    brighten  ...              vertical-flip
# 192                        fog  ...                      shear
# 459                     rotate  ...            horizontal-flip
# 480                     clouds  ...         coarse-salt-pepper
# 430    additive-gaussian-noise  ...                     emboss
# 400             coarse-dropout  ...                      shear
# 359                   brighten  ...            horizontal-flip
# 59                      rotate  ...                translate-x
# 332  add-to-hue-and-saturation  ...  add-to-hue-and-saturation
# 388            horizontal-flip  ...    additive-gaussian-noise
# 371                translate-y  ...                       crop
# 474                     clouds  ...            horizontal-flip
# 100              gaussian-blur  ...                   brighten
# 205                   brighten  ...                     invert
# 226                       crop  ...                     emboss
# 2                       rotate  ...                     rotate
#
#     D_aug1_magnitude                D_aug2_type D_aug2_magnitude  \
# 310            0.259                     emboss            0.671
# 581            0.462                   brighten            0.229
# 170            0.167                     clouds            0.865
# 540            0.037         coarse-salt-pepper            0.358
# 610            0.553            horizontal-flip            0.806
# 37             0.836                    sharpen            0.648
# 516            0.098              vertical-flip            0.588
# 539            0.020                   brighten            0.279
# 142            0.092                     emboss            0.552
# 80             0.451                       crop            0.442
# 565            0.088                     invert            0.221
# 259            0.104                translate-y            0.986
# 139            0.767    additive-gaussian-noise            0.675
# 275            0.043             gamma-contrast            0.806
# 287            0.518                    dropout            0.805
# 60             0.653                   brighten            0.995
# 192            0.171                    dropout            0.875
# 459            0.903                   brighten            0.281
# 480            0.006              vertical-flip            0.650
# 430            0.318              vertical-flip            0.201
# 400            0.910                     rotate            0.451
# 359            0.865  add-to-hue-and-saturation            0.679
# 59             0.135                    sharpen            0.150
# 332            0.027                       crop            0.840
# 388            0.237                    dropout            0.568
# 371            0.878                        fog            0.613
# 474            0.712                translate-x            0.164
# 100            0.841                translate-y            0.398
# 205            0.044             gamma-contrast            0.628
# 226            0.050            horizontal-flip            0.239
# 2              0.000                     rotate            0.000
#
#                    E_aug1_type E_aug1_magnitude              E_aug2_type  \
# 310         coarse-salt-pepper            0.131                   invert
# 581         coarse-salt-pepper            0.137                  sharpen
# 170    additive-gaussian-noise            0.140                     crop
# 540            horizontal-flip            0.132              translate-y
# 610         coarse-salt-pepper            0.115  additive-gaussian-noise
# 37                      emboss            0.957                   rotate
# 516  add-to-hue-and-saturation            0.149                   rotate
# 539                translate-x            0.135       coarse-salt-pepper
# 142                       crop            0.969                  sharpen
# 80               vertical-flip            0.359                  dropout
# 565              gaussian-blur            0.459                   clouds
# 259                     clouds            0.130                     crop
# 139                translate-x            0.313            vertical-flip
# 275             coarse-dropout            0.886                   emboss
# 287              gaussian-blur            0.011                   clouds
# 60              gamma-contrast            0.414                  dropout
# 192            horizontal-flip            0.608           gamma-contrast
# 459                   brighten            0.006              translate-x
# 480         coarse-salt-pepper            0.262           gamma-contrast
# 430                     emboss            0.648                   emboss
# 400                     rotate            0.205              translate-y
# 359             gamma-contrast            0.009  additive-gaussian-noise
# 59                 translate-x            0.386          horizontal-flip
# 332                translate-y            0.347                      fog
# 388             coarse-dropout            0.064                  sharpen
# 371                     invert            0.667                     crop
# 474                translate-x            0.040          horizontal-flip
# 100             gamma-contrast            0.165                   emboss
# 205             gamma-contrast            0.026                      fog
# 226                    sharpen            0.088                   rotate
# 2                       rotate            0.000                   rotate
#
#     E_aug2_magnitude  mean_late_val_acc expected_accuracy_increase(%)
# 310            0.968              0.783                          20.8
# 581            0.990              0.767                          19.2
# 170            0.983              0.750                          17.5
# 540            0.973              0.750                          17.5
# 610            0.161              0.750                          17.5
# 37             0.870              0.725                          15.0
# 516            0.158              0.717                          14.2
# 539            0.968              0.717                          14.2
# 142            0.221              0.700                          12.5
# 80             0.689              0.700                          12.5
# 565            0.987              0.700                          12.5
# 259            0.765              0.700                          12.5
# 139            0.588              0.700                          12.5
# 275            0.790              0.700                          12.5
# 287            0.882              0.700                          12.5
# 60             0.624              0.700                          12.5
# 192            0.784              0.700                          12.5
# 459            0.974              0.700                          12.5
# 480            0.959              0.700                          12.5
# 430            0.982              0.700                          12.5
# 400            0.977              0.700                          12.5
# 359            0.987              0.700                          12.5
# 59             0.450              0.700                          12.5
# 332            0.855              0.700                          12.5
# 388            0.995              0.700                          12.5
# 371            0.932              0.700                          12.5
# 474            0.377              0.667                           9.2
# 100            0.146              0.650                           7.5
# 205            0.946              0.633                           5.8
# 226            0.835              0.633                           5.8
# 2              0.000              0.575                           0.0
#
# [31 rows x 23 columns]

# %%
get_top_policies(pd.read_csv('./autoaugment_results.csv'), 20).to_csv('./top_df',index=False)
