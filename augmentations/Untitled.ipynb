# %%
import pandas as pd

def get_top_policies(df, k):
        """Prints and returns top-k policies

        Policies are ordered by their expected accuracy increas
        Args:
            k (int) top-k
        Returns
            pandas.DataFrame: top-k policies as dataframe
        """
        trial_avg_val_acc_df = (
            df.drop_duplicates(["trial_no", "sample_no"])
            .groupby("trial_no")
            .mean()["mean_late_val_acc"]
            .reset_index()
        )[["trial_no", "mean_late_val_acc"]]

        x_df = pd.merge(
            df.drop(columns=["mean_late_val_acc"]),
            trial_avg_val_acc_df,
            on="trial_no",
            how="left",
        )

        x_df = x_df.sort_values("mean_late_val_acc", ascending=False)

        baseline_val_acc = x_df[x_df["trial_no"] == 0]["mean_late_val_acc"].values[0]

        x_df["expected_accuracy_increase(%)"] = (
            x_df["mean_late_val_acc"] - baseline_val_acc
        )*100

        top_df = x_df.drop_duplicates(["trial_no"]).sort_values(
            "mean_late_val_acc", ascending=False
        )[:k]

        SELECT = [
            "trial_no",
            'A_aug1_type', 'A_aug1_magnitude', 'A_aug2_type', 'A_aug2_magnitude',
            'B_aug1_type', 'B_aug1_magnitude', 'B_aug2_type', 'B_aug2_magnitude',
            'C_aug1_type', 'C_aug1_magnitude', 'C_aug2_type', 'C_aug2_magnitude',
            'D_aug1_type', 'D_aug1_magnitude', 'D_aug2_type', 'D_aug2_magnitude',
            'E_aug1_type', 'E_aug1_magnitude', 'E_aug2_type', 'E_aug2_magnitude',
            "mean_late_val_acc", "expected_accuracy_increase(%)"
        ]
        top_df = top_df[SELECT]

#         print(f"top-{k} policies:", k)
#         print(top_df)

        return top_df

get_top_policies(pd.read_csv('./autoaugment_results.csv'), 105)
# Out:
#      trial_no                A_aug1_type  A_aug1_magnitude  \
# 79          3         coarse-salt-pepper             0.902
# 438        21         histogram-equalize             0.934
# 80          4    additive-gaussian-noise             0.675
# 121         6  add-to-hue-and-saturation             0.704
# 325        16             gamma-contrast             0.910
# 381        19                       crop             0.960
# 522        26    additive-gaussian-noise             0.999
# 292        14              gaussian-blur             1.000
# 159         7            horizontal-flip             0.533
# 474        23                     emboss             0.834
# 550        27              vertical-flip             0.742
# 220        11              vertical-flip             0.734
# 270        13                  grayscale             0.937
# 376        18                     emboss             0.933
# 4           0                     rotate             0.000
# 359        17         coarse-salt-pepper             0.601
# 161         8                      shear             0.097
# 41          2             gamma-contrast             0.801
# 252        12                     invert             0.387
# 111         5      perspective-transform             0.918
# 205        10      perspective-transform             0.986
# 401        20    additive-gaussian-noise             0.097
# 184         9                    dropout             0.420
# 314        15            horizontal-flip             0.734
# 31          1  add-to-hue-and-saturation             0.844
# 512        25              vertical-flip             0.948
# 448        22            horizontal-flip             0.655
# 485        24  add-to-hue-and-saturation             0.843
#
#                A_aug2_type  A_aug2_magnitude                B_aug1_type  \
# 79                  rotate             0.970            horizontal-flip
# 438     coarse-salt-pepper             0.547              gaussian-blur
# 80                  emboss             0.778          elastic-transform
# 121                 emboss             0.433                        fog
# 325         gamma-contrast             0.845                translate-y
# 381                   crop             0.842            horizontal-flip
# 522         gamma-contrast             0.057                      shear
# 292  perspective-transform             0.750                      shear
# 159            translate-y             0.395         coarse-salt-pepper
# 474        horizontal-flip             0.615      perspective-transform
# 550            translate-x             0.149  add-to-hue-and-saturation
# 220            translate-y             0.801                        fog
# 270         gamma-contrast             0.996      perspective-transform
# 376         gamma-contrast             0.967              gaussian-blur
# 4                   rotate             0.000                     rotate
# 359         coarse-dropout             0.027                     rotate
# 161              grayscale             0.260                     invert
# 41                  invert             0.679                        fog
# 252        horizontal-flip             0.900  add-to-hue-and-saturation
# 111            translate-y             0.565               super-pixels
# 205           super-pixels             0.997         coarse-salt-pepper
# 401                dropout             0.769                       crop
# 184          gaussian-blur             0.365                       crop
# 314            translate-y             0.987              vertical-flip
# 31            super-pixels             0.847         coarse-salt-pepper
# 512                 invert             0.741                translate-x
# 448  perspective-transform             0.265                       crop
# 485                   crop             0.223                     emboss
#
#      B_aug1_magnitude                B_aug2_type  B_aug2_magnitude  \
# 79              0.171    additive-gaussian-noise             0.751
# 438             0.729    additive-gaussian-noise             0.643
# 80              0.663                       crop             0.623
# 121             0.396      perspective-transform             0.639
# 325             0.888                     clouds             0.993
# 381             0.494          elastic-transform             0.793
# 522             0.877              gaussian-blur             0.680
# 292             0.191                     rotate             0.616
# 159             0.475             gamma-contrast             0.716
# 474             0.715                translate-y             0.932
# 550             0.031         histogram-equalize             0.322
# 220             0.059          elastic-transform             0.735
# 270             0.360                     invert             0.319
# 376             0.745            horizontal-flip             0.536
# 4               0.000                     rotate             0.000
# 359             0.151             gamma-contrast             0.842
# 161             0.448                     rotate             0.352
# 41              0.582                     invert             0.759
# 252             0.019                     emboss             0.431
# 111             0.509      perspective-transform             0.921
# 205             0.362                       crop             0.293
# 401             0.241                    sharpen             0.762
# 184             0.231                     clouds             0.944
# 314             0.669  add-to-hue-and-saturation             0.696
# 31              0.384                     emboss             0.057
# 512             0.848          elastic-transform             0.182
# 448             0.905            horizontal-flip             0.252
# 485             0.791                       crop             0.014
#
#                  C_aug1_type  ...              D_aug1_type D_aug1_magnitude  \
# 79        coarse-salt-pepper  ...        elastic-transform            0.653
# 438                      fog  ...                      fog            0.093
# 80           horizontal-flip  ...            gaussian-blur            0.451
# 121    perspective-transform  ...                   rotate            0.767
# 325       coarse-salt-pepper  ...            gaussian-blur            0.498
# 381            gaussian-blur  ...    perspective-transform            0.220
# 522           coarse-dropout  ...                   rotate            0.598
# 292              translate-x  ...                  dropout            0.494
# 159                   emboss  ...                   rotate            0.092
# 474                  sharpen  ...              translate-x            0.064
# 550                  sharpen  ...                grayscale            0.232
# 220                   invert  ...                  dropout            0.652
# 270  additive-gaussian-noise  ...              translate-x            0.316
# 376                   invert  ...                   clouds            0.706
# 4                     rotate  ...                   rotate            0.000
# 359                   clouds  ...              translate-x            0.541
# 161           gamma-contrast  ...                 brighten            0.167
# 41                    rotate  ...              translate-y            0.135
# 252           gamma-contrast  ...                     crop            0.762
# 111                   rotate  ...          horizontal-flip            0.841
# 205    perspective-transform  ...                  sharpen            0.574
# 401       coarse-salt-pepper  ...           gamma-contrast            0.562
# 184                      fog  ...              translate-x            0.171
# 314       histogram-equalize  ...              translate-x            0.029
# 31                   sharpen  ...                  dropout            0.836
# 512             super-pixels  ...                   emboss            0.572
# 448                 brighten  ...            gaussian-blur            0.527
# 485       coarse-salt-pepper  ...  additive-gaussian-noise            0.545
#
#                    D_aug2_type D_aug2_magnitude                E_aug1_type  \
# 79          coarse-salt-pepper            0.995  add-to-hue-and-saturation
# 438  add-to-hue-and-saturation            0.846                     invert
# 80                        crop            0.442                  grayscale
# 121             coarse-dropout            0.675                    sharpen
# 325                        fog            0.856             coarse-dropout
# 381                        fog            0.864             coarse-dropout
# 522         histogram-equalize            0.790          elastic-transform
# 292                translate-x            0.654    additive-gaussian-noise
# 159    additive-gaussian-noise            0.552                       crop
# 474                translate-y            0.987                    sharpen
# 550                       crop            0.994                   brighten
# 220          elastic-transform            0.417                     rotate
# 270              vertical-flip            0.650      perspective-transform
# 376                     emboss            0.936    additive-gaussian-noise
# 4                       rotate            0.000                     rotate
# 359                      shear            0.889         histogram-equalize
# 161                     clouds            0.865             coarse-dropout
# 41     additive-gaussian-noise            0.150                translate-y
# 252                  grayscale            0.830                   brighten
# 111                    sharpen            0.398                     invert
# 205         coarse-salt-pepper            0.601                        fog
# 401              gaussian-blur            0.968         histogram-equalize
# 184             gamma-contrast            0.875          elastic-transform
# 314                     emboss            0.801                      shear
# 31     additive-gaussian-noise            0.648                    dropout
# 512              gaussian-blur            0.545          elastic-transform
# 448                   brighten            0.911             coarse-dropout
# 485                      shear            0.823            horizontal-flip
#
#     E_aug1_magnitude                E_aug2_type E_aug2_magnitude  \
# 79             0.414             gamma-contrast            0.624
# 438            0.493                     invert            0.334
# 80             0.359                   brighten            0.689
# 121            0.313                  grayscale            0.588
# 325            0.456             coarse-dropout            0.068
# 381            0.496            horizontal-flip            0.559
# 522            0.456                    dropout            0.538
# 292            0.410                    dropout            0.595
# 159            0.969    additive-gaussian-noise            0.221
# 474            0.496                      shear            0.301
# 550            0.478          elastic-transform            0.584
# 220            0.143                    dropout            0.749
# 270            0.355                    sharpen            0.714
# 376            0.254              gaussian-blur            0.700
# 4              0.000                     rotate            0.000
# 359            0.464                     clouds            0.567
# 161            0.140                       crop            0.983
# 41             0.386      perspective-transform            0.450
# 252            0.485                       crop            0.854
# 111            0.165                    dropout            0.146
# 205            0.919              gaussian-blur            0.544
# 401            0.501    additive-gaussian-noise            0.676
# 184            0.608  add-to-hue-and-saturation            0.784
# 314            0.513  add-to-hue-and-saturation            0.645
# 31             0.957                      shear            0.870
# 512            0.432                        fog            0.345
# 448            0.498             gamma-contrast            0.416
# 485            0.496                       crop            0.959
#
#      mean_late_val_acc expected_accuracy_increase(%)
# 79               0.730                           5.9
# 438              0.715                           4.4
# 80               0.702                           3.1
# 121              0.699                           2.8
# 325              0.694                           2.3
# 381              0.694                           2.3
# 522              0.688                           1.7
# 292              0.687                           1.6
# 159              0.687                           1.6
# 474              0.684                           1.3
# 550              0.683                           1.2
# 220              0.676                           0.5
# 270              0.676                           0.5
# 376              0.675                           0.4
# 4                0.671                           0.0
# 359              0.671                           0.0
# 161              0.670                          -0.1
# 41               0.663                          -0.8
# 252              0.628                          -4.3
# 111              0.579                          -9.2
# 205              0.537                         -13.4
# 401              0.521                         -15.0
# 184              0.514                         -15.7
# 314              0.510                         -16.1
# 31               0.495                         -17.6
# 512              0.477                         -19.4
# 448              0.476                         -19.5
# 485              0.470                         -20.1
#
# [28 rows x 23 columns]

# %%
get_top_policies(pd.read_csv('./autoaugment_results.csv'), 20).to_csv('./top_df',index=False)
