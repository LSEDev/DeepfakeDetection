# %%
import pandas as pd

def get_top_policies(df, k):
        """Prints and returns top-k policies

        Policies are ordered by their expected accuracy increas
        Args:
            k (int) top-k
        Returns
            pandas.DataFrame: top-k policies as dataframe
        """
        trial_avg_val_acc_df = (
            df.drop_duplicates(["trial_no", "sample_no"])
            .groupby("trial_no")
            .mean()["mean_late_val_acc"]
            .reset_index()
        )[["trial_no", "mean_late_val_acc"]]

        x_df = pd.merge(
            df.drop(columns=["mean_late_val_acc"]),
            trial_avg_val_acc_df,
            on="trial_no",
            how="left",
        )

        x_df = x_df.sort_values("mean_late_val_acc", ascending=False)

        baseline_val_acc = x_df[x_df["trial_no"] == 0]["mean_late_val_acc"].values[0]

        x_df["expected_accuracy_increase(%)"] = (
            x_df["mean_late_val_acc"] - baseline_val_acc
        )*100

        top_df = x_df.drop_duplicates(["trial_no"]).sort_values(
            "mean_late_val_acc", ascending=False
        )[:k]

        SELECT = [
            "trial_no",
            'A_aug1_type', 'A_aug1_magnitude', 'A_aug2_type', 'A_aug2_magnitude',
            'B_aug1_type', 'B_aug1_magnitude', 'B_aug2_type', 'B_aug2_magnitude',
            'C_aug1_type', 'C_aug1_magnitude', 'C_aug2_type', 'C_aug2_magnitude',
            'D_aug1_type', 'D_aug1_magnitude', 'D_aug2_type', 'D_aug2_magnitude',
            'E_aug1_type', 'E_aug1_magnitude', 'E_aug2_type', 'E_aug2_magnitude',
            "mean_late_val_acc", "expected_accuracy_increase(%)"
        ]
        top_df = top_df[SELECT]

#         print(f"top-{k} policies:", k)
#         print(top_df)

        return top_df

get_top_policies(pd.read_csv('./autoaugment_results.csv'), 105)
# Out:
#      trial_no                A_aug1_type  A_aug1_magnitude  \
# 602        30               super-pixels             0.813
# 843        42                translate-y             0.714
# 122         6  add-to-hue-and-saturation             0.704
# 421        21      perspective-transform             0.802
# 837        41                   brighten             0.018
# 920        46             coarse-dropout             0.626
# 283        14                translate-x             0.990
# 785        39                     rotate             0.810
# 979        48                      shear             0.798
# 447        22                     emboss             0.826
# 720        36                     rotate             0.803
# 408        20                     invert             0.866
# 100         5      perspective-transform             0.918
# 508        25            horizontal-flip             0.806
# 882        44                     rotate             0.401
# 702        35                     clouds             0.830
# 540        27          elastic-transform             0.804
# 382        19                       crop             0.923
# 650        32  add-to-hue-and-saturation             0.805
# 661        33                   brighten             0.964
# 990        49                        fog             0.593
# 70          3         coarse-salt-pepper             0.902
# 498        24  add-to-hue-and-saturation             0.831
# 318        15          elastic-transform             0.954
# 870        43         histogram-equalize             0.197
# 58          2             gamma-contrast             0.801
# 580        29          elastic-transform             0.801
# 808        40      perspective-transform             0.809
# 0           0                     rotate             0.000
# 520        26         histogram-equalize             0.804
# 744        37                   brighten             0.800
# 20          1  add-to-hue-and-saturation             0.844
# 180         9                    dropout             0.420
# 771        38               super-pixels             0.804
# 260        13                     rotate             0.692
# 99          4    additive-gaussian-noise             0.675
# 210        10  add-to-hue-and-saturation             0.709
# 333        16                    dropout             0.791
# 340        17                     clouds             0.747
# 257        12                      shear             0.715
# 639        31                        fog             0.803
# 230        11              gaussian-blur             0.738
# 689        34                     clouds             0.017
# 469        23                     clouds             0.803
# 900        45  add-to-hue-and-saturation             0.457
# 578        28                        fog             0.798
# 946        47              vertical-flip             0.772
# 377        18                     clouds             0.704
# 159         7            horizontal-flip             0.533
# 179         8                      shear             0.097
#
#                    A_aug2_type  A_aug2_magnitude                B_aug1_type  \
# 602      perspective-transform             0.903                     emboss
# 843                     clouds             0.073                translate-x
# 122                     emboss             0.433                        fog
# 421                    dropout             0.270                   brighten
# 837          elastic-transform             0.096          elastic-transform
# 920                translate-y             0.265              vertical-flip
# 283                     clouds             0.169                     emboss
# 785             coarse-dropout             0.002              vertical-flip
# 979                   brighten             0.127                     rotate
# 447  add-to-hue-and-saturation             0.146          elastic-transform
# 720                translate-x             0.448                        fog
# 408             gamma-contrast             0.056              vertical-flip
# 100                translate-y             0.565               super-pixels
# 508                   brighten             0.800                     rotate
# 882  add-to-hue-and-saturation             0.006         histogram-equalize
# 702                     invert             0.261  add-to-hue-and-saturation
# 540         histogram-equalize             0.443                translate-x
# 382                        fog             0.129                       crop
# 650               super-pixels             0.083                    sharpen
# 661             gamma-contrast             0.898                     rotate
# 990                    dropout             0.034                    sharpen
# 70                      rotate             0.970            horizontal-flip
# 498         coarse-salt-pepper             0.262                      shear
# 318                  grayscale             0.033                    sharpen
# 870                    dropout             0.130         coarse-salt-pepper
# 58                      invert             0.679                        fog
# 580                    dropout             0.168                       crop
# 808                translate-y             0.803            horizontal-flip
# 0                       rotate             0.000                     rotate
# 520         coarse-salt-pepper             0.710                   brighten
# 744              gaussian-blur             0.511  add-to-hue-and-saturation
# 20                super-pixels             0.847         coarse-salt-pepper
# 180              gaussian-blur             0.365                       crop
# 771              gaussian-blur             0.624         coarse-salt-pepper
# 260             coarse-dropout             0.610              gaussian-blur
# 99                      emboss             0.778          elastic-transform
# 210               super-pixels             0.807                    dropout
# 333              vertical-flip             0.374                       crop
# 340                translate-x             0.472               super-pixels
# 257                     clouds             0.925                       crop
# 639                     clouds             0.367                translate-y
# 230                   brighten             0.843                     rotate
# 689                     emboss             0.032                   brighten
# 469               super-pixels             0.774                    dropout
# 900                        fog             0.379      perspective-transform
# 578                translate-y             0.179         coarse-salt-pepper
# 946                translate-x             0.166                     invert
# 377                  grayscale             0.323              vertical-flip
# 159                translate-y             0.395         coarse-salt-pepper
# 179                  grayscale             0.260                     invert
#
#      B_aug1_magnitude                B_aug2_type  B_aug2_magnitude  \
# 602             0.359                     emboss             0.996
# 843             0.972              gaussian-blur             0.008
# 122             0.396      perspective-transform             0.639
# 421             0.991                     emboss             0.713
# 837             0.329                     clouds             0.105
# 920             0.975                     rotate             0.595
# 283             0.083                   brighten             0.970
# 785             0.832  add-to-hue-and-saturation             0.704
# 979             0.992              gaussian-blur             0.452
# 447             0.496                    sharpen             0.984
# 720             0.942                  grayscale             0.585
# 408             0.760             coarse-dropout             0.967
# 100             0.509      perspective-transform             0.921
# 508             0.018      perspective-transform             0.950
# 882             0.378          elastic-transform             0.940
# 702             0.014              vertical-flip             0.954
# 540             0.444         coarse-salt-pepper             0.883
# 382             0.704                     invert             0.912
# 650             0.384                      shear             0.988
# 661             0.484              vertical-flip             0.995
# 990             0.994            horizontal-flip             0.515
# 70              0.171    additive-gaussian-noise             0.751
# 498             0.340                        fog             0.279
# 318             0.772  add-to-hue-and-saturation             0.012
# 870             0.964  add-to-hue-and-saturation             0.590
# 58              0.582                     invert             0.759
# 580             0.650                        fog             0.963
# 808             0.496                     emboss             0.857
# 0               0.000                     rotate             0.000
# 520             0.513            horizontal-flip             0.707
# 744             0.696                     rotate             0.592
# 20              0.384                     emboss             0.057
# 180             0.231                     clouds             0.944
# 771             0.101             gamma-contrast             0.995
# 260             0.404                     emboss             0.784
# 99              0.663                       crop             0.623
# 210             0.739         histogram-equalize             0.613
# 333             0.080    additive-gaussian-noise             0.798
# 340             0.144              vertical-flip             0.243
# 257             0.013                   brighten             1.000
# 639             0.482    additive-gaussian-noise             0.360
# 230             0.369                   brighten             0.664
# 689             0.017                    dropout             0.517
# 469             0.757         histogram-equalize             0.955
# 900             0.412                       crop             0.140
# 578             0.540                     invert             0.780
# 946             0.160             gamma-contrast             0.340
# 377             0.351      perspective-transform             0.688
# 159             0.475             gamma-contrast             0.716
# 179             0.448                     rotate             0.352
#
#                    C_aug1_type  ...                D_aug1_type  \
# 602                  grayscale  ...                translate-y
# 843                    sharpen  ...             gamma-contrast
# 122      perspective-transform  ...                     rotate
# 421  add-to-hue-and-saturation  ...                     rotate
# 837      perspective-transform  ...                     rotate
# 920                     emboss  ...                       crop
# 283                    sharpen  ...                  grayscale
# 785                      shear  ...                        fog
# 979                   brighten  ...                  grayscale
# 447          elastic-transform  ...                    sharpen
# 720             coarse-dropout  ...                     rotate
# 408             gamma-contrast  ...                    sharpen
# 100                     rotate  ...            horizontal-flip
# 508                     rotate  ...          elastic-transform
# 882                    sharpen  ...                     clouds
# 702            horizontal-flip  ...                    sharpen
# 540                      shear  ...         histogram-equalize
# 382                  grayscale  ...             coarse-dropout
# 650            horizontal-flip  ...    additive-gaussian-noise
# 661                     rotate  ...         coarse-salt-pepper
# 990                translate-y  ...                     clouds
# 70          coarse-salt-pepper  ...          elastic-transform
# 498            horizontal-flip  ...               super-pixels
# 318              vertical-flip  ...             coarse-dropout
# 870    additive-gaussian-noise  ...             coarse-dropout
# 58                      rotate  ...                translate-y
# 580             coarse-dropout  ...      perspective-transform
# 808                      shear  ...    additive-gaussian-noise
# 0                       rotate  ...                     rotate
# 520                translate-x  ...              gaussian-blur
# 744            horizontal-flip  ...              vertical-flip
# 20                     sharpen  ...                    dropout
# 180                        fog  ...                translate-x
# 771                     invert  ...    additive-gaussian-noise
# 260             coarse-dropout  ...              gaussian-blur
# 99             horizontal-flip  ...              gaussian-blur
# 210                translate-x  ...    additive-gaussian-noise
# 333               super-pixels  ...                     invert
# 340      perspective-transform  ...                        fog
# 257                  grayscale  ...      perspective-transform
# 639                translate-y  ...                translate-y
# 230         histogram-equalize  ...              vertical-flip
# 689         coarse-salt-pepper  ...                     rotate
# 469              vertical-flip  ...    additive-gaussian-noise
# 900         coarse-salt-pepper  ...                     clouds
# 578                  grayscale  ...    additive-gaussian-noise
# 946                        fog  ...  add-to-hue-and-saturation
# 377              gaussian-blur  ...  add-to-hue-and-saturation
# 159                     emboss  ...                     rotate
# 179             gamma-contrast  ...                   brighten
#
#     D_aug1_magnitude                D_aug2_type D_aug2_magnitude  \
# 602            0.838                     invert            0.169
# 843            0.049                     clouds            0.888
# 122            0.767             coarse-dropout            0.675
# 421            0.896                     clouds            0.815
# 837            0.626                     emboss            0.131
# 920            0.745                    dropout            0.411
# 283            0.474         coarse-salt-pepper            0.987
# 785            0.418          elastic-transform            0.073
# 979            0.303                translate-x            0.682
# 447            0.823                translate-x            0.864
# 720            0.833             gamma-contrast            0.418
# 408            0.541            horizontal-flip            0.809
# 100            0.841                    sharpen            0.398
# 508            0.691                translate-x            0.724
# 882            0.915  add-to-hue-and-saturation            0.065
# 702            0.352                     invert            0.164
# 540            0.903         histogram-equalize            0.716
# 382            0.629                    dropout            0.734
# 650            0.869          elastic-transform            0.734
# 661            0.878      perspective-transform            0.229
# 990            0.250  add-to-hue-and-saturation            0.757
# 70             0.653         coarse-salt-pepper            0.995
# 498            0.152          elastic-transform            0.874
# 318            0.764         coarse-salt-pepper            0.118
# 870            0.181             gamma-contrast            0.632
# 58             0.135    additive-gaussian-noise            0.150
# 580            0.377                translate-y            0.623
# 808            0.952                     invert            0.307
# 0              0.000                     rotate            0.000
# 520            0.937          elastic-transform            0.982
# 744            0.608         coarse-salt-pepper            0.781
# 20             0.836    additive-gaussian-noise            0.648
# 180            0.171             gamma-contrast            0.875
# 771            0.198                     emboss            0.118
# 260            0.739                  grayscale            0.587
# 99             0.451                       crop            0.442
# 210            0.910             gamma-contrast            0.931
# 333            0.323              vertical-flip            0.856
# 340            0.579      perspective-transform            0.554
# 257            0.967                   brighten            0.407
# 639            0.516      perspective-transform            0.670
# 230            0.786                     clouds            0.876
# 689            0.712            horizontal-flip            0.325
# 469            0.525          elastic-transform            0.138
# 900            0.878                    dropout            0.933
# 578            0.258                translate-y            0.784
# 946            0.645    additive-gaussian-noise            0.801
# 377            0.977                    dropout            0.697
# 159            0.092    additive-gaussian-noise            0.552
# 179            0.167                     clouds            0.865
#
#                    E_aug1_type E_aug1_magnitude                E_aug2_type  \
# 602                    sharpen            0.163  add-to-hue-and-saturation
# 843                    sharpen            0.150                      shear
# 122                    sharpen            0.313                  grayscale
# 421                    sharpen            0.184                translate-x
# 837                    sharpen            0.126                translate-y
# 920                    sharpen            0.498                     rotate
# 283                      shear            0.118                    sharpen
# 785                    sharpen            0.131                     invert
# 979    additive-gaussian-noise            0.110          elastic-transform
# 447                    sharpen            0.006         coarse-salt-pepper
# 720             gamma-contrast            0.178            horizontal-flip
# 408                    sharpen            0.194             gamma-contrast
# 100                     invert            0.165                    dropout
# 508                    sharpen            0.156                     rotate
# 882                    sharpen            0.170                    sharpen
# 702            horizontal-flip            0.183                   brighten
# 540                    sharpen            0.094         coarse-salt-pepper
# 382    additive-gaussian-noise            0.240                translate-y
# 650               super-pixels            0.770                translate-y
# 661                     emboss            0.105         coarse-salt-pepper
# 990         histogram-equalize            0.561                   brighten
# 70   add-to-hue-and-saturation            0.414             gamma-contrast
# 498                    sharpen            0.035                     invert
# 318             coarse-dropout            0.261                       crop
# 870                    sharpen            0.990                       crop
# 58                 translate-y            0.386      perspective-transform
# 580               super-pixels            0.009                        fog
# 808      perspective-transform            0.135                    sharpen
# 0                       rotate            0.000                     rotate
# 520                    sharpen            0.302             coarse-dropout
# 744                    sharpen            0.040              gaussian-blur
# 20                     dropout            0.957                      shear
# 180          elastic-transform            0.608  add-to-hue-and-saturation
# 771               super-pixels            0.029         histogram-equalize
# 260                     clouds            0.114                  grayscale
# 99                   grayscale            0.359                   brighten
# 210                      shear            0.043              gaussian-blur
# 333                      shear            0.059  add-to-hue-and-saturation
# 340         histogram-equalize            0.289    additive-gaussian-noise
# 257              gaussian-blur            0.315             coarse-dropout
# 639                    sharpen            0.198                   brighten
# 230                       crop            0.330               super-pixels
# 689         coarse-salt-pepper            0.321             coarse-dropout
# 469                    sharpen            0.076                translate-y
# 900                    sharpen            0.194                    dropout
# 578                    sharpen            0.061                translate-x
# 946                    sharpen            0.180                      shear
# 377                        fog            0.393               super-pixels
# 159                       crop            0.969    additive-gaussian-noise
# 179             coarse-dropout            0.140                       crop
#
#     E_aug2_magnitude  mean_late_val_acc expected_accuracy_increase(%)
# 602            0.423              0.671                          10.7
# 843            0.258              0.667                          10.3
# 122            0.588              0.663                           9.9
# 421            0.673              0.649                           8.5
# 837            0.311              0.647                           8.3
# 920            0.480              0.629                           6.5
# 283            0.598              0.627                           6.3
# 785            0.905              0.626                           6.2
# 979            0.555              0.624                           6.0
# 447            0.461              0.620                           5.6
# 720            0.589              0.619                           5.5
# 408            0.456              0.618                           5.4
# 100            0.146              0.617                           5.3
# 508            0.190              0.616                           5.2
# 882            0.035              0.613                           4.9
# 702            0.283              0.606                           4.2
# 540            0.753              0.599                           3.5
# 382            0.517              0.595                           3.1
# 650            0.983              0.594                           3.0
# 661            0.779              0.594                           3.0
# 990            0.147              0.593                           2.9
# 70             0.624              0.589                           2.5
# 498            0.062              0.587                           2.3
# 318            0.590              0.586                           2.2
# 870            0.578              0.584                           2.0
# 58             0.450              0.577                           1.3
# 580            0.613              0.573                           0.9
# 808            0.734              0.571                           0.7
# 0              0.000              0.564                           0.0
# 520            0.270              0.563                          -0.1
# 744            0.048              0.560                          -0.4
# 20             0.870              0.553                          -1.1
# 180            0.784              0.552                          -1.2
# 771            0.247              0.550                          -1.4
# 260            0.643              0.532                          -3.2
# 99             0.689              0.518                          -4.6
# 210            0.493              0.517                          -4.7
# 333            0.111              0.505                          -5.9
# 340            0.377              0.503                          -6.1
# 257            0.003              0.502                          -6.2
# 639            0.964              0.501                          -6.3
# 230            0.747              0.499                          -6.5
# 689            0.839              0.499                          -6.5
# 469            0.559              0.497                          -6.7
# 900            0.820              0.497                          -6.7
# 578            0.635              0.496                          -6.8
# 946            0.433              0.495                          -6.9
# 377            0.482              0.494                          -7.0
# 159            0.221              0.494                          -7.0
# 179            0.983              0.484                          -8.0
#
# [50 rows x 23 columns]

# %%
get_top_policies(pd.read_csv('./autoaugment_results.csv'), 20).to_csv('./top_df',index=False)
